# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json



# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_df =pd.read_csv("../WeatherPy/output_data/cities.csv")

#drop na value(if there were) and remove unnamed column
cities_df=cities_df.drop(columns=["Unnamed: 0"])
cities_df = cities_df.dropna()

cities_df
# Out:
#                City  Cloudiness Country          Date  Humidity    Lat  \
# 0             Vaini        90.0      TO  1.592531e+09      88.0 -21.20
# 1            Castro        65.0      BR  1.592531e+09      95.0 -24.79
# 2    Cap Malheureux        83.0      MU  1.592531e+09      71.0 -19.98
# 3           Rikitea       100.0      PF  1.592531e+09      91.0 -23.12
# 4     Srednekolymsk         0.0      RU  1.592531e+09      18.0  67.45
# ..              ...         ...     ...           ...       ...    ...
# 594          Anyang       100.0      CN  1.592531e+09      60.0  36.10
# 595         Tarakan       100.0      ID  1.592531e+09      86.0   3.30
# 596      Vanderhoof       100.0      CA  1.592531e+09      53.0  54.02
# 597           Lapua         5.0      FI  1.592531e+09      96.0  62.97
# 598           Kieta        35.0      PG  1.592531e+09      71.0  -6.22
#
#         Lng  Max Temp  Wind Speed
# 0   -175.20     73.40       13.87
# 1    -50.01     57.60        4.88
# 2     57.61     71.01        7.00
# 3   -134.97     73.62       16.37
# 4    153.68     89.47        9.22
# ..      ...       ...         ...
# 594  114.33     80.01        9.06
# 595  117.63     80.51        7.14
# 596 -124.02     69.64        3.42
# 597   23.01     55.00        1.01
# 598  155.63     84.67        3.58
#
# [574 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key = g_key)

# Store 'Lat' and 'Lng' into  locations 
locations = cities_df [["Lat", "Lng"]].astype(float)
weights = cities_df["Humidity"].astype(float)


# Create a Humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=weights , 
                               dissipating=False, max_intensity= max(weights),
                                 point_radius = 5)

fig.add_layer(heat_layer)


# Saves an image of our chart so that we can view it in a folder
plt.savefig("output_data/Fig1.png") 

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # #Analysis: It seems that the humidity is higher in South America in comparison to north america humidity is lower in Algeria, Sudan, Egypt

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
## Narrow down the DataFrame to find your ideal weather condition
new_cities = pd.DataFrame(cities_df, columns = ["City", "Max Temp", "Wind Speed", "Cloudiness"])

# The ideal condition based on the instruction:
# A max temperature lower than 80 degrees but higher than 70.
# Wind speed less than 10 mph.
# Zero cloudiness.
ideal_temp = (new_cities["Max Temp"]<80) & (new_cities["Max Temp"]>70)
ideal_wind = new_cities["Wind Speed"]<10
ideal_cloudiness = new_cities["Cloudiness"]==0

ideal_cities = new_cities.loc[ideal_cloudiness & ideal_temp & ideal_wind]

# %%
ideal_cities
# Out:
#             City  Max Temp  Wind Speed  Cloudiness
# 12         Kieta     78.76        3.18         0.0
# 178     Behshahr     77.00        4.70         0.0
# 193      Angoche     71.20        8.99         0.0
# 217     Hazorasp     71.60        4.70         0.0
# 378   Mossamedes     71.35        2.93         0.0
# 419        Gazli     75.67        6.67         0.0
# 469       Murgab     75.20        6.93         0.0
# 522      Kamenka     71.01        5.01         0.0
# 547  Verkhoyansk     75.96        1.05         0.0

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = pd.DataFrame(cities_df, columns=["City", "Country", "Lat", "Lng"])

#Add a "Hotel Name" column to the DataFrame.
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                      City Country    Lat     Lng Hotel Name
# 0            Puerto Ayora      EC  -0.74  -90.35
# 1                 Ushuaia      AR -54.80  -68.30
# 2                  Manche      FR  49.00   -1.17
# 3              Codrington      AU -38.27  141.97
# 4              Skibbereen      IE  51.55   -9.27
# ..                    ...     ...    ...     ...        ...
# 562                 Hobyo      SO   5.35   48.53
# 563              Barcelos      PT  41.54   -8.62
# 564              Westport      US  41.14  -73.36
# 565                 Bilma      NE  18.69   12.92
# 567  Vila Franca do Campo      PT  37.72  -25.43
#
# [539 rows x 5 columns]

# %%
hotel_name = []

# params dictionary to update each iteration

params = {
    "radius": 5000,
    "types": "hotel",
    "keyword": "hotel",
    "key": g_key,
}



# Loop through the hotel_df and run a lat/long search for each city
for index, row in hotel_df.iterrows():   
# get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]
    
# change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

# Use the search term: "hotel" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# make request 
    hotel_names = requests.get(base_url, params=params).json()

    try:
        hotel_df.loc[index,"Hotel Name"]=hotel_names["results"][0]["name"]

    except IndexError:
        print("Missing field/result... skipping.")
        
# Save Data to csv
hotel_df.to_csv("output_data/hotel.csv")

# Visualize to confirm airport data appears
hotel_df
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
#                      City Country    Lat     Lng  \
# 0            Puerto Ayora      EC  -0.74  -90.35
# 1                 Ushuaia      AR -54.80  -68.30
# 2                  Manche      FR  49.00   -1.17
# 3              Codrington      AU -38.27  141.97
# 4              Skibbereen      IE  51.55   -9.27
# ..                    ...     ...    ...     ...
# 562                 Hobyo      SO   5.35   48.53
# 563              Barcelos      PT  41.54   -8.62
# 564              Westport      US  41.14  -73.36
# 565                 Bilma      NE  18.69   12.92
# 567  Vila Franca do Campo      PT  37.72  -25.43
#
#                                    Hotel Name
# 0                     Hotel Solymar Galapagos
# 1    Wyndham Garden Ushuaia Hotel del Glaciar
# 2     Bed and Breakfast petit coin de paradis
# 3        Codrington Gardens Bed And Breakfast
# 4                         The West Cork Hotel
# ..                                        ...
# 562                              Osmani Hotel
# 563                            Hotel Bagoeira
# 564                 Hilton Garden Inn Norwalk
# 565
# 567                       Pestana Bahia Praia
#
# [539 rows x 5 columns]

# %%
hotel_df.to_csv("output_data/hotel.csv")

# %%
#pprint the hotel names
print(json.dumps(hotel_names, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.7147319,
#                     "lng": -25.469431
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.71635042989272,
#                         "lng": -25.46789047010728
#                     },
#                     "southwest": {
#                         "lat": 37.71365077010728,
#                         "lng": -25.47059012989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "df074519e48dc2428a1cd600b05ec732e715fabe",
#             "name": "Pestana Bahia Praia",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100984817128548599949\">Jose Abambres</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAiBAc-WYivriTR_E215Jn_kt_CEo6mVAg-wyQPq6_dtUhRg8LY_D1pnGaz2KJk7KcO1AlO9VM69ta98rbkZ4kpjnoq1pL7gYgpsO4M0GYYNjm5kPbrFQGs7W67ZQFSqmUEhCwQWPjqfzw_zwnjRG0ajk-GhTy0pco2CrdxwwV389NHABNnYO6XQ",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ1_6FVyYmXQsRiBvZiD8MaEw",
#             "plus_code": {
#                 "compound_code": "PG7J+V6 Vila Franca do Campo, Portugal",
#                 "global_code": "899PPG7J+V6"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ1_6FVyYmXQsRiBvZiD8MaEw",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 723,
#             "vicinity": "Praia de \u00c1gua d'Alto Apartado 8, Vila Franca Do Campo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.7141485,
#                     "lng": -25.4357291
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.71554437989272,
#                         "lng": -25.43438927010728
#                     },
#                     "southwest": {
#                         "lat": 37.71284472010728,
#                         "lng": -25.43708892989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2b5a80b9cff85a093d848cb4d50d9a306f886d33",
#             "name": "A Villa by the Sea",
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115055708786198194140\">Visitors In Manchester</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAFzngcWm2lKifHbGGlSwLIsaZOGHxPAYT6Nlig_mS0KSNYPIl2r6pJBCPuSl6VJomEU5R2d9__WZz_WtiKMdbix9wuZUtz-unhfXvBAAeiqt7y-PT20po2778H51vAXAEhDSMJwqVQbdlCSu_kEDtOuPGhSrn0rVdSTriye12GbjEoXw6blhSg",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJ7RIMfGcmXQsRq0VX1InBJwg",
#             "plus_code": {
#                 "compound_code": "PH77+MP Vila Franca do Campo, Portugal",
#                 "global_code": "899PPH77+MP"
#             },
#             "rating": 5,
#             "reference": "ChIJ7RIMfGcmXQsRq0VX1InBJwg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 15,
#             "vicinity": "Rua do Castelo n.o1, Vila Franca Do Campo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.71627429999999,
#                     "lng": -25.4287796
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.71762412989272,
#                         "lng": -25.42742977010728
#                     },
#                     "southwest": {
#                         "lat": 37.71492447010728,
#                         "lng": -25.43012942989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e56ef99dbd69ae3163513843e317b4809fb7507e",
#             "name": "Vinha d'Areia Beach Hotel",
#             "photos": [
#                 {
#                     "height": 2672,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109867862148279918942\">Almut Martens</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA-mduKHscjXhSP8eIJ7HBpCDPFwxF3anYwt6a5YQvu-p5nfnI1lgrXQux07SoGwoqijGa58ZFNDtMC8WrG7WN-RHH474ldeATT6--CteddMQgujaj2SnqtHSG6TWBhwdOEhCgr5NmVnQKJPvoeGivsQahGhQWWYnx7Jb7h8zDuLuyi8ttBPi1Mg",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJ8a0cfmAmXQsRaft23YLLRcE",
#             "plus_code": {
#                 "compound_code": "PH8C+GF Vila Franca do Campo, Portugal",
#                 "global_code": "899PPH8C+GF"
#             },
#             "rating": 3.8,
#             "reference": "ChIJ8a0cfmAmXQsRaft23YLLRcE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 127,
#             "vicinity": "Vila Franca do Campo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.7168552,
#                     "lng": -25.4266904
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.71850927989272,
#                         "lng": -25.42510847010728
#                     },
#                     "southwest": {
#                         "lat": 37.71580962010728,
#                         "lng": -25.42780812989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9c4338be7e52c656c7b5baaa99b4a1865380a18f",
#             "name": "Praia Vinha D'Areia",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116527835004004251458\">Brian Miranda</a>"
#                     ],
#                     "photo_reference": "CmRaAAAASOj2bP4RprCwUCnWUWTwFnku_yZLB530BUMLq4pEdmwmfpbuku0JsTFVLkjNhBfkJSmZs_jJocn8o3qtMfexjwe4cEMG4vjk8QjcizFTMy6_zMM29CBA9qeehBdmL806EhASZYC2REK7TXET2HhwZi7PGhTEP_wfL6ic9j_gkPE1Oof7Y5j5Yg",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJaecrBmAmXQsRLpBtkpadwPE",
#             "plus_code": {
#                 "compound_code": "PH8F+P8 Vila Franca do Campo, Portugal",
#                 "global_code": "899PPH8F+P8"
#             },
#             "rating": 4.4,
#             "reference": "ChIJaecrBmAmXQsRLpBtkpadwPE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 422,
#             "vicinity": "R. Eng. Martins Mota, Vila Franca Do Campo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.7152286,
#                     "lng": -25.3736318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.71659237989272,
#                         "lng": -25.37227427010728
#                     },
#                     "southwest": {
#                         "lat": 37.71389272010728,
#                         "lng": -25.37497392989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "570ae0f4e5ffa1d51e239fdda92fd2e745774993",
#             "name": "Moradia T5 Ponta Gar\u00e7a",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110872563949259625180\">Alex Fern\u00e1ndez Eyre</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAP3RIpY_2wkSdfU6NaPBIjKdM__vGkaFjzHDOnmvlUErSB_zuWKSV1foPdBY1hYYI9GSNGchPZuqxjNMbyHzPhxMJGZqDp3ZQdmgJCug7m2o4gMIdBTqgnBorFeLDT-bJEhAApoPl0Ia1ts-PxoxVXitAGhQUQOpzHZAS5ifACi1Sb0US1Zv82Q",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ8asz6VMhXQsREUIFCBGG8OI",
#             "plus_code": {
#                 "compound_code": "PJ8G+3G Ponta Garca, Portugal",
#                 "global_code": "899PPJ8G+3G"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ8asz6VMhXQsREUIFCBGG8OI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "Rua Miguel In\u00e1cio 43, Ponta Gar\u00e7a"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.7149918,
#                     "lng": -25.4363034
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.71634212989272,
#                         "lng": -25.43496007010728
#                     },
#                     "southwest": {
#                         "lat": 37.71364247010728,
#                         "lng": -25.43765972989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ab4016aab9410c882b21f7977ddcef120b218b55",
#             "name": "Apartamentos Francisco Martins",
#             "photos": [
#                 {
#                     "height": 3492,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102461579975186659418\">\u0412\u043b\u0430\u0434\u0438\u043c\u0438\u0440 \u0412\u043b\u0430\u0434\u0438\u043c\u0438\u0440\u043e\u0432\u0438\u0447</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQ4wlMTbxyFWK0eRC-CWjw5OxzN69pC1K95EjonK4onzRrNhEbHDVQgYXS4oebR4M1bBCoW4LaSbQ77cSfDpA8iuYllcy56UI3xdI4A05iyaW1RqIdaMlN1Mbdn5-ZN4iEhCIsDSvykKzkW24UkgLzmk_GhTk-beImfT8wto3bnu9zBLOoO-qtw",
#                     "width": 4656
#                 }
#             ],
#             "place_id": "ChIJEfFPi2cmXQsRCQEvlvwemB8",
#             "plus_code": {
#                 "compound_code": "PH77+XF Vila Franca do Campo, Portugal",
#                 "global_code": "899PPH77+XF"
#             },
#             "rating": 4.9,
#             "reference": "ChIJEfFPi2cmXQsRCQEvlvwemB8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 43,
#             "vicinity": "Rua Doutor Augusto Botelho Simas 11 - 11D, Vila Franca Do Campo"
#         }
#     ],
#     "status": "OK"
# }

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add the layer to the map
fig.add_layer(markers)


# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
